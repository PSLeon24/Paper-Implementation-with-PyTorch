# %% [markdown]
# # 1. Import Dependencies

# %%
import torch
import matplotlib
import matplotlib.pyplot as plt
import time
import h5py
import torch.optim as optim
import torch.nn as nn
import numpy as np
import math
from torchvision.transforms import ToPILImage
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from torchvision.utils import save_image
# %matplotlib inline

import torch.nn as nn
import torch.nn.functional as F
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# # 2. Load Dataset

# %%
# 입력 이미지 차원 설정하기
input_h, input_w = 33, 33 # sub-image에 대한 크기
out_h, out_w = 33, 33 # label인 high-resolution에 대한 크기

# sub-images와 label 읽어오기
file = h5py.File('data/train_mscale.h5')
in_train = file['data'][:] # train data
out_train = file['label'][:] # train label
file.close()

# float32로 타입 변경
in_train = in_train.astype('float32')
out_train = out_train.astype('float32')

# 0.75: 0.15 = train : val 분할
(x_train, x_val, y_train, y_val) = train_test_split(in_train, out_train, test_size=0.25)
print(x_train.shape[0])
print(x_val.shape[0])
print(f"total shape is {x_train.shape[0] + x_val.shape[0] + y_train.shape[0] + y_val.shape[0]}")
# Out:
# 16368
# 5456
# total shape is 43648

# %%
class SRCNNDataset(Dataset):
    def __init__(self, image_data, labels):
        self.image_data = image_data
        self.labels = labels

    def __len__(self):
        return (len(self.image_data))

    def __getitem__(self, index):
        image = self.image_data[index]
        label = self.labels[index]
        return (torch.tensor(image, dtype=torch.float),
            torch.tensor(label, dtype=torch.float))

# %%
# 데이터셋 생성
train_ds = SRCNNDataset(x_train, y_train)
val_ds = SRCNNDataset(x_val, y_val)

# 데이터로더 생성
train_dl = DataLoader(train_ds, batch_size=64)
val_dl = DataLoader(val_ds, batch_size=64)

# %%
for x, y in train_dl:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([64, 1, 33, 33]) torch.Size([64, 1, 33, 33])

# %%
from torchvision.transforms.functional import to_pil_image

# 데이터로부터 하나의 배치를 가져옴
data_iter = iter(train_dl)
img, target = next(data_iter)

# 배치에서 첫 번째 이미지를 선택
img = img[0]
target = target[0]

plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(to_pil_image(img), cmap='gray')
plt.title('train')
plt.subplot(1, 2, 2)
plt.imshow(to_pil_image(target), cmap='gray')
plt.title('target')
plt.show()

# %% [markdown]
# # 3. Model Construction

# %%
# f1 = 9, f2 = 1, f3 = 5, n1 = 64, n2 = 32
# f is kernel size
# n is output channels

class SRCNN(nn.Module):
    def __init__(self):
        super().__init__()

        # padding_mode='replicate'는 zero padding이 아닌, 주변 값을 복사해서 padding 합니다.
        self.conv1 = nn.Conv2d(1, 64, 9, padding=2, padding_mode='replicate')
        self.conv2 = nn.Conv2d(64, 32, 1, padding=2, padding_mode='replicate')
        self.conv3 = nn.Conv2d(32, 1, 5, padding=2, padding_mode='replicate')

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.conv3(x)

        return x

# %%
# 가중치 초기화
model = SRCNN().to(device)

def initialize_weights(model):
    classname = model.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)

model.apply(initialize_weights);

# %% [markdown]
# # 4. Train the Model

# %%
# 손실함수
loss_func = nn.MSELoss()

# optimizer
import torch.optim as optim
optimizer = optim.Adam(model.parameters())

# %%
# PSNR function: 모델의 출력값과 high-resoultion의 유사도를 측정
# PSNR 값이 클수록 좋음
def psnr(label, outputs, max_val=1.):
    label = label.cpu().detach().numpy()
    outputs = outputs.cpu().detach().numpy()
    img_diff = outputs - label
    rmse = math.sqrt(np.mean((img_diff)**2))
    if rmse == 0: # label과 output이 완전히 일치하는 경우
        return 100
    else:
        psnr = 20 * math.log10(max_val/rmse)
        return psnr

# %%
# train 함수
def train(model, data_dl):
    model.train()
    running_loss = 0.0
    running_psnr = 0.0

    for ba, data in enumerate(data_dl):
        image = data[0].to(device)
        label = data[1].to(device)

        optimizer.zero_grad()
        outputs = model(image)
        loss = loss_func(outputs, label)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        batch_psnr = psnr(label, outputs)
        running_psnr += batch_psnr
    
    final_loss = running_loss / len(data_dl.dataset)
    final_psnr = running_psnr / int(len(train_ds)/data_dl.batch_size)
    return final_loss, final_psnr

# %%
# validation 함수
def validate(model, data_dl, epoch):
    # epoch는 이미지를 저장할때, 이미지의 이름으로 사용됩니다.
    
    model.eval()
    running_loss = 0.0
    running_psnr = 0.0
    with torch.no_grad():
        for ba, data in enumerate(data_dl):
            image = data[0].to(device)
            label = data[1].to(device)

            outputs = model(image)
            loss = loss_func(outputs, label)

            running_loss += loss.item()
            batch_psnr = psnr(label,outputs)
            running_psnr += batch_psnr

        outputs = outputs.cpu()
        # tensor를 입력받아 이미지 파일로 저장합니다.
        save_image(outputs, f'outputs/{epoch}.png')
    
    final_loss = running_loss / len(data_dl.dataset)
    final_psnr = running_psnr / int(len(val_ds)/data_dl.batch_size)
    return final_loss, final_psnr

# %%
# 이미지를 저장할 폴더 생성
# !mkdir outputs
# Out:
# mkdir: `outputs' 디렉토리를 만들 수 없습니다: 파일이 있습니다

# %%
num_epochs = 300

# 학습하기
train_loss, val_loss = [], []
train_psnr, val_psnr = [], []
start = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1} of {num_epochs}')
    train_epoch_loss, train_epoch_psnr = train(model, train_dl)
    val_epoch_loss, val_epoch_psnr = validate(model, val_dl, epoch)

    train_loss.append(train_epoch_loss)
    train_psnr.append(train_epoch_psnr)
    val_loss.append(val_epoch_loss)
    val_psnr.append(val_epoch_psnr)
    end = time.time()
    print(f'Train PSNR: {train_epoch_psnr:.3f}, Val PSNR: {val_epoch_psnr:.3f}, Time: {end-start:.2f} sec')
# Out:
# Epoch 1 of 300
# Train PSNR: 22.776, Val PSNR: 25.968, Time: 1.80 sec
# Epoch 2 of 300
# Train PSNR: 25.839, Val PSNR: 26.195, Time: 3.32 sec
# Epoch 3 of 300
# Train PSNR: 26.136, Val PSNR: 26.621, Time: 4.82 sec
# Epoch 4 of 300
# Train PSNR: 26.682, Val PSNR: 27.119, Time: 6.36 sec
# Epoch 5 of 300
# Train PSNR: 26.946, Val PSNR: 27.210, Time: 7.91 sec
# Epoch 6 of 300
# Train PSNR: 27.020, Val PSNR: 27.289, Time: 9.41 sec
# Epoch 7 of 300
# Train PSNR: 27.063, Val PSNR: 27.324, Time: 10.91 sec
# Epoch 8 of 300
# Train PSNR: 27.082, Val PSNR: 27.344, Time: 12.41 sec
# Epoch 9 of 300
# Train PSNR: 27.100, Val PSNR: 27.364, Time: 13.90 sec
# Epoch 10 of 300
# Train PSNR: 27.124, Val PSNR: 27.374, Time: 15.46 sec
# Epoch 11 of 300
# Train PSNR: 27.129, Val PSNR: 27.400, Time: 16.97 sec
# Epoch 12 of 300
# Train PSNR: 27.140, Val PSNR: 27.413, Time: 18.47 sec
# Epoch 13 of 300
# Train PSNR: 27.144, Val PSNR: 27.426, Time: 19.97 sec
# Epoch 14 of 300
# Train PSNR: 27.158, Val PSNR: 27.435, Time: 21.48 sec
# Epoch 15 of 300
# Train PSNR: 27.170, Val PSNR: 27.438, Time: 22.96 sec
# Epoch 16 of 300
# Train PSNR: 27.174, Val PSNR: 27.457, Time: 24.45 sec
# Epoch 17 of 300
# Train PSNR: 27.183, Val PSNR: 27.467, Time: 25.94 sec
# Epoch 18 of 300
# Train PSNR: 27.184, Val PSNR: 27.476, Time: 27.42 sec
# Epoch 19 of 300
# Train PSNR: 27.204, Val PSNR: 27.484, Time: 28.92 sec
# Epoch 20 of 300
# Train PSNR: 27.217, Val PSNR: 27.476, Time: 30.50 sec
# Epoch 21 of 300
# Train PSNR: 27.213, Val PSNR: 27.504, Time: 32.02 sec
# Epoch 22 of 300
# Train PSNR: 27.232, Val PSNR: 27.508, Time: 33.52 sec
# Epoch 23 of 300
# Train PSNR: 27.235, Val PSNR: 27.521, Time: 35.00 sec
# Epoch 24 of 300
# Train PSNR: 27.249, Val PSNR: 27.525, Time: 36.50 sec
# Epoch 25 of 300
# Train PSNR: 27.255, Val PSNR: 27.536, Time: 38.02 sec
# Epoch 26 of 300
# Train PSNR: 27.259, Val PSNR: 27.540, Time: 39.52 sec
# Epoch 27 of 300
# Train PSNR: 27.275, Val PSNR: 27.550, Time: 40.99 sec
# Epoch 28 of 300
# Train PSNR: 27.282, Val PSNR: 27.555, Time: 42.48 sec
# Epoch 29 of 300
# Train PSNR: 27.289, Val PSNR: 27.565, Time: 43.95 sec
# Epoch 30 of 300
# Train PSNR: 27.294, Val PSNR: 27.571, Time: 45.43 sec
# Epoch 31 of 300
# Train PSNR: 27.301, Val PSNR: 27.581, Time: 46.90 sec
# Epoch 32 of 300
# Train PSNR: 27.307, Val PSNR: 27.587, Time: 48.37 sec
# Epoch 33 of 300
# Train PSNR: 27.316, Val PSNR: 27.589, Time: 49.84 sec
# Epoch 34 of 300
# Train PSNR: 27.324, Val PSNR: 27.600, Time: 51.31 sec
# Epoch 35 of 300
# Train PSNR: 27.328, Val PSNR: 27.606, Time: 52.79 sec
# Epoch 36 of 300
# Train PSNR: 27.338, Val PSNR: 27.616, Time: 54.26 sec
# Epoch 37 of 300
# Train PSNR: 27.346, Val PSNR: 27.625, Time: 55.73 sec
# Epoch 38 of 300
# Train PSNR: 27.356, Val PSNR: 27.634, Time: 57.20 sec
# Epoch 39 of 300
# Train PSNR: 27.361, Val PSNR: 27.641, Time: 58.72 sec
# Epoch 40 of 300
# Train PSNR: 27.373, Val PSNR: 27.652, Time: 60.23 sec
# Epoch 41 of 300
# Train PSNR: 27.379, Val PSNR: 27.660, Time: 61.72 sec
# Epoch 42 of 300
# Train PSNR: 27.387, Val PSNR: 27.671, Time: 63.22 sec
# Epoch 43 of 300
# Train PSNR: 27.394, Val PSNR: 27.674, Time: 64.70 sec
# Epoch 44 of 300
# Train PSNR: 27.400, Val PSNR: 27.681, Time: 66.18 sec
# Epoch 45 of 300
# Train PSNR: 27.407, Val PSNR: 27.681, Time: 67.67 sec
# Epoch 46 of 300
# Train PSNR: 27.412, Val PSNR: 27.692, Time: 69.15 sec
# Epoch 47 of 300
# Train PSNR: 27.422, Val PSNR: 27.689, Time: 70.65 sec
# Epoch 48 of 300
# Train PSNR: 27.424, Val PSNR: 27.706, Time: 72.16 sec
# Epoch 49 of 300
# Train PSNR: 27.432, Val PSNR: 27.689, Time: 73.67 sec
# Epoch 50 of 300
# Train PSNR: 27.450, Val PSNR: 27.666, Time: 75.18 sec
# Epoch 51 of 300
# Train PSNR: 27.422, Val PSNR: 27.721, Time: 76.66 sec
# Epoch 52 of 300
# Train PSNR: 27.451, Val PSNR: 27.729, Time: 78.18 sec
# Epoch 53 of 300
# Train PSNR: 27.452, Val PSNR: 27.727, Time: 79.70 sec
# Epoch 54 of 300
# Train PSNR: 27.465, Val PSNR: 27.595, Time: 81.17 sec
# Epoch 55 of 300
# Train PSNR: 27.474, Val PSNR: 27.677, Time: 82.65 sec
# Epoch 56 of 300
# Train PSNR: 27.432, Val PSNR: 26.930, Time: 84.14 sec
# Epoch 57 of 300
# Train PSNR: 27.459, Val PSNR: 27.759, Time: 85.62 sec
# Epoch 58 of 300
# Train PSNR: 27.511, Val PSNR: 27.762, Time: 87.09 sec
# Epoch 59 of 300
# Train PSNR: 27.499, Val PSNR: 27.649, Time: 88.56 sec
# Epoch 60 of 300
# Train PSNR: 27.495, Val PSNR: 27.775, Time: 90.03 sec
# Epoch 61 of 300
# Train PSNR: 27.509, Val PSNR: 27.703, Time: 91.51 sec
# Epoch 62 of 300
# Train PSNR: 27.492, Val PSNR: 27.784, Time: 92.98 sec
# Epoch 63 of 300
# Train PSNR: 27.509, Val PSNR: 27.776, Time: 94.45 sec
# Epoch 64 of 300
# Train PSNR: 27.529, Val PSNR: 27.765, Time: 95.92 sec
# Epoch 65 of 300
# Train PSNR: 27.515, Val PSNR: 27.742, Time: 97.39 sec
# Epoch 66 of 300
# Train PSNR: 27.528, Val PSNR: 27.775, Time: 98.86 sec
# Epoch 67 of 300
# Train PSNR: 27.534, Val PSNR: 27.806, Time: 100.34 sec
# Epoch 68 of 300
# Train PSNR: 27.518, Val PSNR: 27.816, Time: 101.81 sec
# Epoch 69 of 300
# Train PSNR: 27.554, Val PSNR: 27.835, Time: 103.28 sec
# Epoch 70 of 300
# Train PSNR: 27.530, Val PSNR: 27.837, Time: 104.75 sec
# Epoch 71 of 300
# Train PSNR: 27.558, Val PSNR: 27.741, Time: 106.22 sec
# Epoch 72 of 300
# Train PSNR: 27.552, Val PSNR: 27.797, Time: 107.72 sec
# Epoch 73 of 300
# Train PSNR: 27.571, Val PSNR: 27.745, Time: 109.22 sec
# Epoch 74 of 300
# Train PSNR: 27.568, Val PSNR: 27.730, Time: 110.76 sec
# Epoch 75 of 300
# Train PSNR: 27.566, Val PSNR: 27.866, Time: 112.29 sec
# Epoch 76 of 300
# Train PSNR: 27.583, Val PSNR: 27.782, Time: 113.76 sec
# Epoch 77 of 300
# Train PSNR: 27.588, Val PSNR: 27.728, Time: 115.23 sec
# Epoch 78 of 300
# Train PSNR: 27.589, Val PSNR: 27.816, Time: 116.70 sec
# Epoch 79 of 300
# Train PSNR: 27.595, Val PSNR: 27.755, Time: 118.17 sec
# Epoch 80 of 300
# Train PSNR: 27.599, Val PSNR: 27.700, Time: 119.64 sec
# Epoch 81 of 300
# Train PSNR: 27.603, Val PSNR: 27.652, Time: 121.11 sec
# Epoch 82 of 300
# Train PSNR: 27.610, Val PSNR: 27.697, Time: 122.59 sec
# Epoch 83 of 300
# Train PSNR: 27.612, Val PSNR: 27.628, Time: 124.06 sec
# Epoch 84 of 300
# Train PSNR: 27.620, Val PSNR: 27.659, Time: 125.53 sec
# Epoch 85 of 300
# Train PSNR: 27.626, Val PSNR: 27.786, Time: 127.01 sec
# Epoch 86 of 300
# Train PSNR: 27.615, Val PSNR: 27.839, Time: 128.48 sec
# Epoch 87 of 300
# Train PSNR: 27.640, Val PSNR: 27.890, Time: 129.96 sec
# Epoch 88 of 300
# Train PSNR: 27.628, Val PSNR: 27.883, Time: 131.43 sec
# Epoch 89 of 300
# Train PSNR: 27.647, Val PSNR: 27.907, Time: 132.90 sec
# Epoch 90 of 300
# Train PSNR: 27.634, Val PSNR: 27.932, Time: 134.37 sec
# Epoch 91 of 300
# Train PSNR: 27.649, Val PSNR: 27.945, Time: 135.85 sec
# Epoch 92 of 300
# Train PSNR: 27.662, Val PSNR: 27.893, Time: 137.33 sec
# Epoch 93 of 300
# Train PSNR: 27.657, Val PSNR: 27.976, Time: 138.81 sec
# Epoch 94 of 300
# Train PSNR: 27.668, Val PSNR: 27.878, Time: 140.28 sec
# Epoch 95 of 300
# Train PSNR: 27.674, Val PSNR: 27.960, Time: 141.76 sec
# Epoch 96 of 300
# Train PSNR: 27.663, Val PSNR: 27.927, Time: 143.23 sec
# Epoch 97 of 300
# Train PSNR: 27.662, Val PSNR: 27.848, Time: 144.70 sec
# Epoch 98 of 300
# Train PSNR: 27.693, Val PSNR: 27.969, Time: 146.18 sec
# Epoch 99 of 300
# Train PSNR: 27.689, Val PSNR: 27.959, Time: 147.65 sec
# Epoch 100 of 300
# Train PSNR: 27.675, Val PSNR: 27.928, Time: 149.12 sec
# Epoch 101 of 300
# Train PSNR: 27.701, Val PSNR: 27.958, Time: 150.60 sec
# Epoch 102 of 300
# Train PSNR: 27.682, Val PSNR: 27.743, Time: 152.07 sec
# Epoch 103 of 300
# Train PSNR: 27.711, Val PSNR: 27.740, Time: 153.55 sec
# Epoch 104 of 300
# Train PSNR: 27.712, Val PSNR: 28.005, Time: 155.02 sec
# Epoch 105 of 300
# Train PSNR: 27.699, Val PSNR: 27.982, Time: 156.49 sec
# Epoch 106 of 300
# Train PSNR: 27.715, Val PSNR: 28.002, Time: 157.96 sec
# Epoch 107 of 300
# Train PSNR: 27.709, Val PSNR: 28.033, Time: 159.43 sec
# Epoch 108 of 300
# Train PSNR: 27.708, Val PSNR: 27.982, Time: 160.90 sec
# Epoch 109 of 300
# Train PSNR: 27.714, Val PSNR: 27.847, Time: 162.38 sec
# Epoch 110 of 300
# Train PSNR: 27.695, Val PSNR: 28.041, Time: 163.84 sec
# Epoch 111 of 300
# Train PSNR: 27.758, Val PSNR: 28.040, Time: 165.32 sec
# Epoch 112 of 300
# Train PSNR: 27.717, Val PSNR: 28.001, Time: 166.78 sec
# Epoch 113 of 300
# Train PSNR: 27.734, Val PSNR: 27.954, Time: 168.27 sec
# Epoch 114 of 300
# Train PSNR: 27.731, Val PSNR: 27.953, Time: 169.83 sec
# Epoch 115 of 300
# Train PSNR: 27.715, Val PSNR: 27.924, Time: 171.33 sec
# Epoch 116 of 300
# Train PSNR: 27.750, Val PSNR: 28.028, Time: 172.82 sec
# Epoch 117 of 300
# Train PSNR: 27.742, Val PSNR: 28.041, Time: 174.33 sec
# Epoch 118 of 300
# Train PSNR: 27.728, Val PSNR: 28.036, Time: 175.86 sec
# Epoch 119 of 300
# Train PSNR: 27.746, Val PSNR: 27.922, Time: 177.35 sec
# Epoch 120 of 300
# Train PSNR: 27.758, Val PSNR: 27.937, Time: 178.83 sec
# Epoch 121 of 300
# Train PSNR: 27.750, Val PSNR: 28.072, Time: 180.35 sec
# Epoch 122 of 300
# Train PSNR: 27.742, Val PSNR: 28.074, Time: 181.84 sec
# Epoch 123 of 300
# Train PSNR: 27.740, Val PSNR: 28.076, Time: 183.33 sec
# Epoch 124 of 300
# Train PSNR: 27.738, Val PSNR: 27.949, Time: 184.81 sec
# Epoch 125 of 300
# Train PSNR: 27.766, Val PSNR: 28.073, Time: 186.30 sec
# Epoch 126 of 300
# Train PSNR: 27.745, Val PSNR: 27.997, Time: 187.78 sec
# Epoch 127 of 300
# Train PSNR: 27.752, Val PSNR: 27.874, Time: 189.26 sec
# Epoch 128 of 300
# Train PSNR: 27.764, Val PSNR: 27.907, Time: 190.74 sec
# Epoch 129 of 300
# Train PSNR: 27.767, Val PSNR: 27.854, Time: 192.26 sec
# Epoch 130 of 300
# Train PSNR: 27.773, Val PSNR: 28.085, Time: 193.73 sec
# Epoch 131 of 300
# Train PSNR: 27.753, Val PSNR: 28.097, Time: 195.22 sec
# Epoch 132 of 300
# Train PSNR: 27.760, Val PSNR: 28.058, Time: 196.70 sec
# Epoch 133 of 300
# Train PSNR: 27.767, Val PSNR: 28.100, Time: 198.19 sec
# Epoch 134 of 300
# Train PSNR: 27.760, Val PSNR: 28.062, Time: 199.68 sec
# Epoch 135 of 300
# Train PSNR: 27.756, Val PSNR: 27.997, Time: 201.19 sec
# Epoch 136 of 300
# Train PSNR: 27.765, Val PSNR: 28.101, Time: 202.68 sec
# Epoch 137 of 300
# Train PSNR: 27.790, Val PSNR: 28.031, Time: 204.16 sec
# Epoch 138 of 300
# Train PSNR: 27.769, Val PSNR: 27.808, Time: 205.65 sec
# Epoch 139 of 300
# Train PSNR: 27.784, Val PSNR: 27.934, Time: 207.13 sec
# Epoch 140 of 300
# Train PSNR: 27.776, Val PSNR: 27.868, Time: 208.61 sec
# Epoch 141 of 300
# Train PSNR: 27.763, Val PSNR: 28.113, Time: 210.10 sec
# Epoch 142 of 300
# Train PSNR: 27.800, Val PSNR: 27.991, Time: 211.58 sec
# Epoch 143 of 300
# Train PSNR: 27.784, Val PSNR: 28.119, Time: 213.06 sec
# Epoch 144 of 300
# Train PSNR: 27.770, Val PSNR: 28.100, Time: 214.55 sec
# Epoch 145 of 300
# Train PSNR: 27.786, Val PSNR: 28.122, Time: 216.03 sec
# Epoch 146 of 300
# Train PSNR: 27.787, Val PSNR: 28.124, Time: 217.51 sec
# Epoch 147 of 300
# Train PSNR: 27.777, Val PSNR: 28.113, Time: 218.98 sec
# Epoch 148 of 300
# Train PSNR: 27.777, Val PSNR: 27.939, Time: 220.46 sec
# Epoch 149 of 300
# Train PSNR: 27.797, Val PSNR: 28.117, Time: 221.95 sec
# Epoch 150 of 300
# Train PSNR: 27.799, Val PSNR: 27.966, Time: 223.43 sec
# Epoch 151 of 300
# Train PSNR: 27.765, Val PSNR: 28.127, Time: 224.92 sec
# Epoch 152 of 300
# Train PSNR: 27.815, Val PSNR: 28.121, Time: 226.40 sec
# Epoch 153 of 300
# Train PSNR: 27.803, Val PSNR: 27.987, Time: 227.88 sec
# Epoch 154 of 300
# Train PSNR: 27.753, Val PSNR: 28.111, Time: 229.35 sec
# Epoch 155 of 300
# Train PSNR: 27.835, Val PSNR: 28.097, Time: 230.86 sec
# Epoch 156 of 300
# Train PSNR: 27.801, Val PSNR: 28.079, Time: 232.35 sec
# Epoch 157 of 300
# Train PSNR: 27.793, Val PSNR: 28.140, Time: 233.84 sec
# Epoch 158 of 300
# Train PSNR: 27.799, Val PSNR: 28.083, Time: 235.34 sec
# Epoch 159 of 300
# Train PSNR: 27.801, Val PSNR: 28.141, Time: 236.81 sec
# Epoch 160 of 300
# Train PSNR: 27.802, Val PSNR: 28.066, Time: 238.29 sec
# Epoch 161 of 300
# Train PSNR: 27.796, Val PSNR: 27.993, Time: 239.79 sec
# Epoch 162 of 300
# Train PSNR: 27.763, Val PSNR: 28.132, Time: 241.26 sec
# Epoch 163 of 300
# Train PSNR: 27.846, Val PSNR: 28.093, Time: 242.74 sec
# Epoch 164 of 300
# Train PSNR: 27.811, Val PSNR: 28.100, Time: 244.29 sec
# Epoch 165 of 300
# Train PSNR: 27.810, Val PSNR: 28.102, Time: 245.82 sec
# Epoch 166 of 300
# Train PSNR: 27.809, Val PSNR: 28.150, Time: 247.32 sec
# Epoch 167 of 300
# Train PSNR: 27.800, Val PSNR: 28.010, Time: 248.81 sec
# Epoch 168 of 300
# Train PSNR: 27.811, Val PSNR: 28.133, Time: 250.30 sec
# Epoch 169 of 300
# Train PSNR: 27.828, Val PSNR: 27.926, Time: 251.84 sec
# Epoch 170 of 300
# Train PSNR: 27.809, Val PSNR: 28.110, Time: 253.31 sec
# Epoch 171 of 300
# Train PSNR: 27.779, Val PSNR: 28.138, Time: 254.78 sec
# Epoch 172 of 300
# Train PSNR: 27.857, Val PSNR: 28.147, Time: 256.25 sec
# Epoch 173 of 300
# Train PSNR: 27.816, Val PSNR: 28.081, Time: 257.72 sec
# Epoch 174 of 300
# Train PSNR: 27.829, Val PSNR: 28.129, Time: 259.19 sec
# Epoch 175 of 300
# Train PSNR: 27.781, Val PSNR: 28.140, Time: 260.66 sec
# Epoch 176 of 300
# Train PSNR: 27.857, Val PSNR: 28.031, Time: 262.13 sec
# Epoch 177 of 300
# Train PSNR: 27.815, Val PSNR: 28.109, Time: 263.60 sec
# Epoch 178 of 300
# Train PSNR: 27.829, Val PSNR: 28.100, Time: 265.08 sec
# Epoch 179 of 300
# Train PSNR: 27.828, Val PSNR: 28.075, Time: 266.54 sec
# Epoch 180 of 300
# Train PSNR: 27.846, Val PSNR: 28.117, Time: 268.01 sec
# Epoch 181 of 300
# Train PSNR: 27.825, Val PSNR: 28.151, Time: 269.48 sec
# Epoch 182 of 300
# Train PSNR: 27.818, Val PSNR: 28.126, Time: 270.95 sec
# Epoch 183 of 300
# Train PSNR: 27.832, Val PSNR: 28.126, Time: 272.43 sec
# Epoch 184 of 300
# Train PSNR: 27.828, Val PSNR: 28.100, Time: 273.89 sec
# Epoch 185 of 300
# Train PSNR: 27.824, Val PSNR: 28.080, Time: 275.43 sec
# Epoch 186 of 300
# Train PSNR: 27.830, Val PSNR: 28.125, Time: 276.98 sec
# Epoch 187 of 300
# Train PSNR: 27.830, Val PSNR: 28.102, Time: 278.48 sec
# Epoch 188 of 300
# Train PSNR: 27.826, Val PSNR: 28.108, Time: 279.99 sec
# Epoch 189 of 300
# Train PSNR: 27.839, Val PSNR: 28.147, Time: 281.46 sec
# Epoch 190 of 300
# Train PSNR: 27.827, Val PSNR: 28.105, Time: 282.94 sec
# Epoch 191 of 300
# Train PSNR: 27.835, Val PSNR: 28.125, Time: 284.41 sec
# Epoch 192 of 300
# Train PSNR: 27.838, Val PSNR: 28.136, Time: 285.88 sec
# Epoch 193 of 300
# Train PSNR: 27.834, Val PSNR: 28.152, Time: 287.35 sec
# Epoch 194 of 300
# Train PSNR: 27.832, Val PSNR: 28.141, Time: 288.82 sec
# Epoch 195 of 300
# Train PSNR: 27.846, Val PSNR: 28.165, Time: 290.29 sec
# Epoch 196 of 300
# Train PSNR: 27.831, Val PSNR: 28.150, Time: 291.76 sec
# Epoch 197 of 300
# Train PSNR: 27.839, Val PSNR: 28.170, Time: 293.24 sec
# Epoch 198 of 300
# Train PSNR: 27.843, Val PSNR: 28.161, Time: 294.71 sec
# Epoch 199 of 300
# Train PSNR: 27.839, Val PSNR: 28.151, Time: 296.18 sec
# Epoch 200 of 300
# Train PSNR: 27.841, Val PSNR: 28.134, Time: 297.65 sec
# Epoch 201 of 300
# Train PSNR: 27.841, Val PSNR: 28.130, Time: 299.12 sec
# Epoch 202 of 300
# Train PSNR: 27.822, Val PSNR: 28.068, Time: 300.59 sec
# Epoch 203 of 300
# Train PSNR: 27.854, Val PSNR: 28.178, Time: 302.07 sec
# Epoch 204 of 300
# Train PSNR: 27.869, Val PSNR: 28.166, Time: 303.54 sec
# Epoch 205 of 300
# Train PSNR: 27.852, Val PSNR: 28.162, Time: 305.01 sec
# Epoch 206 of 300
# Train PSNR: 27.800, Val PSNR: 28.179, Time: 306.48 sec
# Epoch 207 of 300
# Train PSNR: 27.897, Val PSNR: 28.170, Time: 307.96 sec
# Epoch 208 of 300
# Train PSNR: 27.850, Val PSNR: 28.152, Time: 309.43 sec
# Epoch 209 of 300
# Train PSNR: 27.850, Val PSNR: 28.143, Time: 310.90 sec
# Epoch 210 of 300
# Train PSNR: 27.853, Val PSNR: 28.189, Time: 312.38 sec
# Epoch 211 of 300
# Train PSNR: 27.838, Val PSNR: 28.136, Time: 313.86 sec
# Epoch 212 of 300
# Train PSNR: 27.853, Val PSNR: 28.173, Time: 315.33 sec
# Epoch 213 of 300
# Train PSNR: 27.881, Val PSNR: 28.124, Time: 316.79 sec
# Epoch 214 of 300
# Train PSNR: 27.846, Val PSNR: 28.096, Time: 318.26 sec
# Epoch 215 of 300
# Train PSNR: 27.865, Val PSNR: 28.154, Time: 319.73 sec
# Epoch 216 of 300
# Train PSNR: 27.841, Val PSNR: 28.069, Time: 321.20 sec
# Epoch 217 of 300
# Train PSNR: 27.870, Val PSNR: 28.114, Time: 322.69 sec
# Epoch 218 of 300
# Train PSNR: 27.838, Val PSNR: 28.188, Time: 324.17 sec
# Epoch 219 of 300
# Train PSNR: 27.890, Val PSNR: 28.172, Time: 325.64 sec
# Epoch 220 of 300
# Train PSNR: 27.851, Val PSNR: 28.074, Time: 327.11 sec
# Epoch 221 of 300
# Train PSNR: 27.872, Val PSNR: 28.196, Time: 328.58 sec
# Epoch 222 of 300
# Train PSNR: 27.885, Val PSNR: 28.193, Time: 330.05 sec
# Epoch 223 of 300
# Train PSNR: 27.861, Val PSNR: 28.107, Time: 331.52 sec
# Epoch 224 of 300
# Train PSNR: 27.823, Val PSNR: 28.197, Time: 332.99 sec
# Epoch 225 of 300
# Train PSNR: 27.914, Val PSNR: 28.208, Time: 334.46 sec
# Epoch 226 of 300
# Train PSNR: 27.855, Val PSNR: 28.191, Time: 335.93 sec
# Epoch 227 of 300
# Train PSNR: 27.869, Val PSNR: 28.193, Time: 337.40 sec
# Epoch 228 of 300
# Train PSNR: 27.877, Val PSNR: 28.154, Time: 338.87 sec
# Epoch 229 of 300
# Train PSNR: 27.856, Val PSNR: 28.203, Time: 340.34 sec
# Epoch 230 of 300
# Train PSNR: 27.882, Val PSNR: 28.207, Time: 341.81 sec
# Epoch 231 of 300
# Train PSNR: 27.876, Val PSNR: 28.161, Time: 343.28 sec
# Epoch 232 of 300
# Train PSNR: 27.860, Val PSNR: 28.201, Time: 344.75 sec
# Epoch 233 of 300
# Train PSNR: 27.883, Val PSNR: 28.195, Time: 346.22 sec
# Epoch 234 of 300
# Train PSNR: 27.878, Val PSNR: 28.023, Time: 347.69 sec
# Epoch 235 of 300
# Train PSNR: 27.891, Val PSNR: 28.195, Time: 349.16 sec
# Epoch 236 of 300
# Train PSNR: 27.853, Val PSNR: 28.188, Time: 350.63 sec
# Epoch 237 of 300
# Train PSNR: 27.895, Val PSNR: 28.090, Time: 352.11 sec
# Epoch 238 of 300
# Train PSNR: 27.882, Val PSNR: 28.147, Time: 353.58 sec
# Epoch 239 of 300
# Train PSNR: 27.864, Val PSNR: 28.216, Time: 355.06 sec
# Epoch 240 of 300
# Train PSNR: 27.896, Val PSNR: 28.162, Time: 356.53 sec
# Epoch 241 of 300
# Train PSNR: 27.845, Val PSNR: 28.213, Time: 358.00 sec
# Epoch 242 of 300
# Train PSNR: 27.908, Val PSNR: 28.197, Time: 359.47 sec
# Epoch 243 of 300
# Train PSNR: 27.914, Val PSNR: 28.212, Time: 360.96 sec
# Epoch 244 of 300
# Train PSNR: 27.886, Val PSNR: 28.155, Time: 362.43 sec
# Epoch 245 of 300
# Train PSNR: 27.864, Val PSNR: 28.194, Time: 363.92 sec
# Epoch 246 of 300
# Train PSNR: 27.852, Val PSNR: 28.219, Time: 365.39 sec
# Epoch 247 of 300
# Train PSNR: 27.915, Val PSNR: 28.208, Time: 366.85 sec
# Epoch 248 of 300
# Train PSNR: 27.902, Val PSNR: 28.180, Time: 368.32 sec
# Epoch 249 of 300
# Train PSNR: 27.898, Val PSNR: 28.207, Time: 369.79 sec
# Epoch 250 of 300
# Train PSNR: 27.898, Val PSNR: 28.175, Time: 371.26 sec
# Epoch 251 of 300
# Train PSNR: 27.905, Val PSNR: 28.142, Time: 372.74 sec
# Epoch 252 of 300
# Train PSNR: 27.880, Val PSNR: 28.209, Time: 374.21 sec
# Epoch 253 of 300
# Train PSNR: 27.869, Val PSNR: 28.211, Time: 375.75 sec
# Epoch 254 of 300
# Train PSNR: 27.922, Val PSNR: 28.211, Time: 377.26 sec
# Epoch 255 of 300
# Train PSNR: 27.907, Val PSNR: 28.186, Time: 378.73 sec
# Epoch 256 of 300
# Train PSNR: 27.862, Val PSNR: 28.223, Time: 380.20 sec
# Epoch 257 of 300
# Train PSNR: 27.936, Val PSNR: 28.171, Time: 381.67 sec
# Epoch 258 of 300
# Train PSNR: 27.882, Val PSNR: 28.232, Time: 383.14 sec
# Epoch 259 of 300
# Train PSNR: 27.909, Val PSNR: 28.227, Time: 384.61 sec
# Epoch 260 of 300
# Train PSNR: 27.914, Val PSNR: 28.205, Time: 386.08 sec
# Epoch 261 of 300
# Train PSNR: 27.869, Val PSNR: 28.222, Time: 387.56 sec
# Epoch 262 of 300
# Train PSNR: 27.911, Val PSNR: 28.213, Time: 389.03 sec
# Epoch 263 of 300
# Train PSNR: 27.942, Val PSNR: 28.234, Time: 390.51 sec
# Epoch 264 of 300
# Train PSNR: 27.865, Val PSNR: 28.120, Time: 391.98 sec
# Epoch 265 of 300
# Train PSNR: 27.954, Val PSNR: 28.185, Time: 393.45 sec
# Epoch 266 of 300
# Train PSNR: 27.915, Val PSNR: 28.228, Time: 394.92 sec
# Epoch 267 of 300
# Train PSNR: 27.933, Val PSNR: 28.250, Time: 396.39 sec
# Epoch 268 of 300
# Train PSNR: 27.914, Val PSNR: 28.174, Time: 397.86 sec
# Epoch 269 of 300
# Train PSNR: 27.885, Val PSNR: 28.221, Time: 399.33 sec
# Epoch 270 of 300
# Train PSNR: 27.931, Val PSNR: 28.231, Time: 400.82 sec
# Epoch 271 of 300
# Train PSNR: 27.920, Val PSNR: 28.238, Time: 402.32 sec
# Epoch 272 of 300
# Train PSNR: 27.894, Val PSNR: 28.250, Time: 403.80 sec
# Epoch 273 of 300
# Train PSNR: 27.931, Val PSNR: 28.234, Time: 405.27 sec
# Epoch 274 of 300
# Train PSNR: 27.915, Val PSNR: 28.151, Time: 406.76 sec
# Epoch 275 of 300
# Train PSNR: 27.949, Val PSNR: 28.233, Time: 408.23 sec
# Epoch 276 of 300
# Train PSNR: 27.906, Val PSNR: 28.096, Time: 409.71 sec
# Epoch 277 of 300
# Train PSNR: 27.939, Val PSNR: 28.165, Time: 411.22 sec
# Epoch 278 of 300
# Train PSNR: 27.884, Val PSNR: 28.234, Time: 412.69 sec
# Epoch 279 of 300
# Train PSNR: 27.908, Val PSNR: 27.955, Time: 414.20 sec
# Epoch 280 of 300
# Train PSNR: 27.959, Val PSNR: 28.082, Time: 415.70 sec
# Epoch 281 of 300
# Train PSNR: 27.938, Val PSNR: 28.186, Time: 417.17 sec
# Epoch 282 of 300
# Train PSNR: 27.912, Val PSNR: 28.054, Time: 418.65 sec
# Epoch 283 of 300
# Train PSNR: 27.939, Val PSNR: 28.190, Time: 420.12 sec
# Epoch 284 of 300
# Train PSNR: 27.915, Val PSNR: 28.201, Time: 421.61 sec
# Epoch 285 of 300
# Train PSNR: 27.946, Val PSNR: 28.220, Time: 423.13 sec
# Epoch 286 of 300
# Train PSNR: 27.924, Val PSNR: 28.218, Time: 424.61 sec
# Epoch 287 of 300
# Train PSNR: 27.937, Val PSNR: 28.208, Time: 426.09 sec
# Epoch 288 of 300
# Train PSNR: 27.929, Val PSNR: 28.248, Time: 427.56 sec
# Epoch 289 of 300
# Train PSNR: 27.943, Val PSNR: 28.120, Time: 429.04 sec
# Epoch 290 of 300
# Train PSNR: 27.940, Val PSNR: 28.042, Time: 430.53 sec
# Epoch 291 of 300
# Train PSNR: 27.939, Val PSNR: 28.226, Time: 432.02 sec
# Epoch 292 of 300
# Train PSNR: 27.876, Val PSNR: 28.231, Time: 433.54 sec
# Epoch 293 of 300
# Train PSNR: 27.979, Val PSNR: 28.190, Time: 435.13 sec
# Epoch 294 of 300
# Train PSNR: 27.911, Val PSNR: 28.265, Time: 436.69 sec
# Epoch 295 of 300
# Train PSNR: 27.962, Val PSNR: 28.090, Time: 438.22 sec
# Epoch 296 of 300
# Train PSNR: 27.928, Val PSNR: 28.142, Time: 439.72 sec
# Epoch 297 of 300
# Train PSNR: 27.954, Val PSNR: 28.213, Time: 441.23 sec
# Epoch 298 of 300
# Train PSNR: 27.943, Val PSNR: 28.075, Time: 442.72 sec
# Epoch 299 of 300
# Train PSNR: 27.935, Val PSNR: 28.004, Time: 444.29 sec
# Epoch 300 of 300
# Train PSNR: 27.955, Val PSNR: 28.241, Time: 445.85 sec

# %%
# loss plots
plt.figure(figsize=(10, 7))
plt.plot(train_loss, color='orange', label='train loss')
plt.plot(val_loss, color='red', label='validataion loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# psnr plots
plt.figure(figsize=(10, 7))
plt.plot(train_psnr, color='green', label='train PSNR dB')
plt.plot(val_psnr, color='blue', label='validataion PSNR dB')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.show()

# %% [markdown]
# # 5. Test

# %%
# 이미지 꺼내기
for img, label in val_dl:
    img = img[0]
    label = label[0]
    break

# super-resolution
model.eval()
with torch.no_grad():
    img_ = img.unsqueeze(0)
    img_ = img_.to(device)
    output = model(img_)
    output = output.squeeze(0)

# 시각화
plt.figure(figsize=(15,15))
plt.subplot(1,3,1)
plt.imshow(to_pil_image(img))
plt.title('input')
plt.subplot(1,3,2)
plt.imshow(to_pil_image(output))
plt.title('output')
plt.subplot(1,3,3)
plt.imshow(to_pil_image(label))
plt.title('ground_truth')
# Out:
# Text(0.5, 1.0, 'ground_truth')

# %% [markdown]
# # References
# - [1] https://deep-learning-study.tistory.com/688
# - [2] https://mole-starseeker.tistory.com/82
